# %%
url = "https://www.theguardian.com/business/2026/jan/04/battery-electric-cars-diesels-great-britain-london-ulez"

# %%
part = url.split("/")
"/".join(part[:3])
# Out:
# 'https://www.theguardian.com'
